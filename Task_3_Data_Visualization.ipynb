# %% [markdown]
# # ✅ 1️⃣ Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
data = {
    'Month': ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'],
    'Sales': [1200,1500,1800,1700,2100,2400,2600,2500,2300,2200,2000,1900],
    'Profit': [200,300,400,350,500,600,650,620,580,540,480,450],
    'Category': ['Electronics','Clothing','Furniture','Electronics','Clothing','Furniture',
                 'Electronics','Clothing','Furniture','Electronics','Clothing','Furniture']
}

df = pd.DataFrame(data)
df
# Out:
#    Month  Sales  Profit     Category
# 0    Jan   1200     200  Electronics
# 1    Feb   1500     300     Clothing
# 2    Mar   1800     400    Furniture
# 3    Apr   1700     350  Electronics
# 4    May   2100     500     Clothing
# 5    Jun   2400     600    Furniture
# 6    Jul   2600     650  Electronics
# 7    Aug   2500     620     Clothing
# 8    Sep   2300     580    Furniture
# 9    Oct   2200     540  Electronics
# 10   Nov   2000     480     Clothing
# 11   Dec   1900     450    Furniture

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Month     12 non-null     object
#  1   Sales     12 non-null     int64
#  2   Profit    12 non-null     int64
#  3   Category  12 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 516.0+ bytes
#              Sales      Profit
# count    12.000000   12.000000
# mean   2016.666667  472.500000
# std     419.595765  138.572265
# min    1200.000000  200.000000
# 25%    1775.000000  387.500000
# 50%    2050.000000  490.000000
# 75%    2325.000000  585.000000
# max    2600.000000  650.000000

# %% [markdown]
# # Line Chart – Monthly Sales Trend

# %%
plt.figure(figsize=(10,5))
plt.plot(df['Month'], df['Sales'], marker='o')
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# # Bar Chart – Profit by Month

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Month', y='Profit', data=df)
plt.title("Monthly Profit Distribution")
plt.show()

# %% [markdown]
# # Pie Chart – Category Distribution

# %%
category_counts = df['Category'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%')
plt.title("Sales by Category")
plt.show()

# %% [markdown]
# # Scatter Plot – Sales vs Profit

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='Sales', y='Profit', data=df)
plt.title("Sales vs Profit Relationship")
plt.show()

# %% [markdown]
# # Dashboard-Style View

# %%
fig, axes = plt.subplots(2,2, figsize=(14,10))

sns.lineplot(ax=axes[0,0], x='Month', y='Sales', data=df)
axes[0,0].set_title("Sales Trend")

sns.barplot(ax=axes[0,1], x='Month', y='Profit', data=df)
axes[0,1].set_title("Profit Distribution")

sns.scatterplot(ax=axes[1,0], x='Sales', y='Profit', data=df)
axes[1,0].set_title("Sales vs Profit")

axes[1,1].pie(category_counts, labels=category_counts.index, autopct='%1.1f%%')
axes[1,1].set_title("Category Share")

plt.tight_layout()
plt.show()

# %%
'''📌 Data Story & Insights

- Sales show steady growth from January to July.
- Peak sales occur in mid-year.
- Profit increases proportionally with sales.
- Electronics and Clothing dominate sales categories.
- Strong correlation exists between Sales and Profit.

These insights help businesses plan inventory and marketing strategies efficiently.'''
# Out:
# '📌 Data Story & Insights\n\n- Sales show steady growth from January to July.\n- Peak sales occur in mid-year.\n- Profit increases proportionally with sales.\n- Electronics and Clothing dominate sales categories.\n- Strong correlation exists between Sales and Profit.\n\nThese insights help businesses plan inventory and marketing strategies efficiently.'

# %%
'''# Task 3 – Data Visualization

This project demonstrates transforming raw data into meaningful visual insights using Python.

## Tools Used
- Python
- Pandas
- Matplotlib
- Seaborn
- Jupyter Notebook

## Visualizations
- Line Chart (Sales Trend)
- Bar Chart (Profit Distribution)
- Pie Chart (Category Share)
- Scatter Plot (Sales vs Profit)
- Dashboard Layout

## Insights
The visuals reveal sales growth patterns, profit relationships, and category performance to support decision-making.

## Author
Saylee
'''
# Out:
# '# Task 3 – Data Visualization\n\nThis project demonstrates transforming raw data into meaningful visual insights using Python.\n\n## Tools Used\n- Python\n- Pandas\n- Matplotlib\n- Seaborn\n- Jupyter Notebook\n\n## Visualizations\n- Line Chart (Sales Trend)\n- Bar Chart (Profit Distribution)\n- Pie Chart (Category Share)\n- Scatter Plot (Sales vs Profit)\n- Dashboard Layout\n\n## Insights\nThe visuals reveal sales growth patterns, profit relationships, and category performance to support decision-making.\n\n## Author\nSaylee\n'
